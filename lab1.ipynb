# %%
import pandas as pd
import numpy as np
from google.colab import drive

# %%
market_fact= pd.read_csv("/content/market_fact.csv")
cust_dimen= pd.read_csv("/content/cust_dimen.csv")
orders_dimen= pd.read_csv("/content/orders_dimen.csv")
prod_dimen = pd.read_csv("/content/prod_dimen.csv")
shipping_dimen = pd.read_csv("/content/shipping_dimen.csv")

# %%
market_fact.set_index('Ord_id', inplace=True)

# %%
market_fact.head()
# Out:
#           Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#            Profit  Shipping_Cost  Product_Base_Margin
# Ord_id
# Ord_5446   -30.51           3.60                 0.56
# Ord_5406     4.56           0.93                 0.54
# Ord_5446  1148.90           2.50                 0.59
# Ord_5456   729.34          14.30                 0.37
# Ord_5485  1219.87          26.30                 0.38

# %% [markdown]
# data illoc

# %%
market_fact.iloc[[3,7,8]]
# Out:
#           Prod_id   Ship_id    Cust_id      Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09              43
# Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10              48
# Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01              33
#
#            Profit  Shipping_Cost  Product_Base_Margin
# Ord_id
# Ord_5456   729.34          14.30                 0.37
# Ord_4725  1137.91           0.99                 0.55
# Ord_4725    45.84           0.71                 0.52

# %%
market_fact.head()
# Out:
#           Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#            Profit  Shipping_Cost  Product_Base_Margin
# Ord_id
# Ord_5446   -30.51           3.60                 0.56
# Ord_5406     4.56           0.93                 0.54
# Ord_5446  1148.90           2.50                 0.59
# Ord_5456   729.34          14.30                 0.37
# Ord_5485  1219.87          26.30                 0.38

# %%
market_fact.loc[(market_fact.Sales>2000) & (market_fact.Sales<3000)]
# Out:
#           Prod_id   Ship_id    Cust_id      Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09              43
# Ord_5205   Prod_4  SHP_7274  Cust_1749  2546.5235      0.09              26
# Ord_5481  Prod_15  SHP_7659  Cust_1820  2700.7800      0.06              29
# Ord_139   Prod_17   SHP_186    Cust_45  2671.2100      0.06              14
# Ord_239    Prod_4   SHP_332    Cust_45  2157.3085      0.00              38
# ...           ...       ...        ...        ...       ...             ...
# Ord_3584  Prod_15  SHP_4961  Cust_1266  2502.6700      0.10               9
# Ord_3592   Prod_4  SHP_4973  Cust_1266  2614.3705      0.07              25
# Ord_3639  Prod_10  SHP_5038  Cust_1266  2173.2600      0.00              35
# Ord_2696   Prod_4  SHP_3691  Cust_1006  2836.0505      0.01              25
# Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08              28
#
# ...

# %%
market_fact.loc[(market_fact.Sales>2000) != (market_fact.Profit<3000)]
# Out:
#           Prod_id   Ship_id    Cust_id   Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446  Prod_16  SHP_7609  Cust_1818  136.81      0.01              23
# Ord_5406  Prod_13  SHP_7549  Cust_1818   42.27      0.01              13
# Ord_5446   Prod_6  SHP_7608  Cust_1818  164.02      0.03              23
# Ord_31    Prod_12    SHP_41    Cust_26   14.76      0.01               5
# Ord_4725  Prod_13  SHP_6593  Cust_1641  162.00      0.01              33
# ...           ...       ...        ...     ...       ...             ...
# Ord_5384   Prod_9  SHP_7519  Cust_1798  181.50      0.08              43
# Ord_5348   Prod_8  SHP_7470  Cust_1798  356.72      0.07               9
# Ord_5411   Prod_6  SHP_7555  Cust_1798  127.16      0.10              20
# Ord_5388   Prod_6  SHP_7524  Cust_1798  243.05      0.02              39
# Ord_5459   Prod_6  SHP_7628  Cust_1798  603.69      0.00              47
#
#           Profit  Shipping_Cost  Product_Base_Margin
# Ord_id
# ...

# %%
market_fact.loc[(market_fact.Sales>2000) | (market_fact.Profit<3000)]
# Out:
#           Prod_id   Ship_id    Cust_id      Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01              23
# Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01              13
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00              26
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09              43
# Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08              35
# ...           ...       ...        ...        ...       ...             ...
# Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08              28
# Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10              20
# Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02              39
# Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03              23
# Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00              47
#
# ...

# %%
market_fact.loc[(market_fact.Ship_id) != (market_fact.Cust_id)]
# Out:
#           Prod_id   Ship_id    Cust_id      Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01              23
# Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01              13
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00              26
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09              43
# Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08              35
# ...           ...       ...        ...        ...       ...             ...
# Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08              28
# Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10              20
# Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02              39
# Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03              23
# Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00              47
#
# ...
